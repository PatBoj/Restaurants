# %%
import osmnx as ox
from pathlib import Path
import os
import geopandas as gpd

from mclights.get_data import get_data_osmx_or_local

project_dir = Path(os.getcwd()).parent
temp_data_dir = project_dir / "temp_data"
raw_data_dir = project_dir / "raw_data"

# %%
restaurants = get_data_osmx_or_local(
    raw_data_dir / "restaurants.gpkg",
    {"amenity": ["bar", "biergarten", "cafe", "fast_food", "food_court", "ice_cream", "pub", "restaurant"]}
)

restaurants = restaurants[["amenity", "name", "cuisine", "addr:city", "name:pl", "name:en"]]
